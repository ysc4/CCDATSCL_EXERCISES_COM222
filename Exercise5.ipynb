# %% [markdown]
# <a href="https://colab.research.google.com/github/ysc4/CCDATSCL_EXERCISES_COM222/blob/main/Exercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 5

# %%
import pandas as pd
import numpy as np

from scipy import stats
from scipy.stats import chi2_contingency

# %% [markdown]
# ## Part 1: ANOVA
#
# A teacher wants to investigate whether different teaching methods affect students’ exam scores. The dataset contains 50 students, each assigned to one of three teaching methods (A, B, or C).
#
# Question: "Is there a difference in mean exam scores among students taught using three different teaching methods?"
#
# - Independent variable (factor): Teaching Method (A, B, C)
# - Dependent variable: Exam Score (numeric)

# %%
url = "https://github.com/robitussin/CCDATSCL_EXERCISES/blob/f56f00991116fcb717a8827d324aa6f599dea366/exam_scores.csv?raw=true"

df_exam_scores = pd.read_csv(url)
df_exam_scores
# Out:
#     StudentID Method  Score
# 0           1      A     79
# 1           2      A     77
# 2           3      A     82
# 3           4      A     75
# 4           5      A     80
# 5           6      A     78
# 6           7      A     83
# 7           8      A     76
# 8           9      A     81
# 9          10      A     74
# 10         11      A     79
# 11         12      A     77
# 12         13      A     80
# 13         14      A     78
# 14         15      A     76
# 15         16      A     82
# 16         17      A     79
# 17         18      B     88
# 18         19      B     85
# 19         20      B     82
# 20         21      B     87
# 21         22      B     90
# 22         23      B     84
# 23         24      B     86
# 24         25      B     83
# 25         26      B     88
# 26         27      B     85
# 27         28      B     86
# 28         29      B     87
# 29         30      B     89
# 30         31      B     84
# 31         32      B     90
# 32         33      B     85
# 33         34      B     88
# 34         35      C     70
# 35         36      C     74
# 36         37      C     72
# 37         38      C     71
# 38         39      C     73
# 39         40      C     69
# 40         41      C     72
# 41         42      C     75
# 42         43      C     70
# 43         44      C     74
# 44         45      C     71
# 45         46      C     73
# 46         47      C     72
# 47         48      C     74
# 48         49      C     70
# 49         50      C     71

# %% [markdown]
# Calculate the number of students in each teaching method.

# %%
# put your answer here

df_exam_scores = df_exam_scores.drop(columns=['StudentID'])
df_exam_scores.groupby('Method').count()
# Out:
#         Score
# Method
# A          17
# B          17
# C          16

# %% [markdown]
# Compute the mean and standard deviation of exam scores for each group.

# %%
# put your answer here

df_exam_scores.groupby('Method')['Score'].agg(['mean', 'std'])
# Out:
#              mean       std
# Method
# A       78.588235  2.575336
# B       86.294118  2.365500
# C       71.937500  1.768945

# %% [markdown]
# Use a plot to show the exam scores by teaching method.

# %%
# put your answer here

df_exam_scores.boxplot(column='Score', by='Method', figsize=(8, 6))
# Out:
# <Axes: title={'center': 'Score'}, xlabel='Method'>

# %%
print('Null Hypothesis: There is no significant difference in mean exam scores among students taught using three different teaching methods.')
print('Alternative Hypothesis: There is a significant difference in mean exam scores among students taught using three different teaching methods.')
# Out:
# Null Hypothesis: There is no significant difference in mean exam scores among students taught using three different teaching methods.
# Alternative Hypothesis: There is a significant difference in mean exam scores among students taught using three different teaching methods.

# %% [markdown]
# Perform the ANOVA Test
# - Use scipy.stats.f_oneway to conduct a one-way ANOVA.
# - Report the F-statistic and p-value.
# - Using a significance level of α = 0.05, state whether you reject or fail to reject H₀.

# %%
# put your answer here
method_a = df_exam_scores[df_exam_scores['Method'] == 'A']
method_b = df_exam_scores[df_exam_scores['Method'] == 'B']
method_c = df_exam_scores[df_exam_scores['Method'] == 'C']

f_statistic, p_value = stats.f_oneway(method_a['Score'], method_b['Score'], method_c['Score'])

print('F-statistic: ', f_statistic)
print('p-value: ', p_value)
# Out:
# F-statistic:  165.17845596593054
# p-value:  5.5032645988699085e-22

# %% [markdown]
# Interpret the results. What does it say about the relationship between teaching method and exam scores?

# %%
# put your answer here

print('Question: Is there a difference in mean exam scores among students taught using three different teaching methods?')

if p_value < 0.05:
    print('\nReject H0. There is a significant difference in mean exam scores among students taught using three different teaching methods.')
else:
    print('\nFail to reject H0. There is no significant difference in mean exam scores among students taught using three different teaching methods.')
# Out:
# Question: Is there a difference in mean exam scores among students taught using three different teaching methods?
#
# Reject H0. There is a significant difference in mean exam scores among students taught using three different teaching methods.

# %% [markdown]
# ## Part 2: Chi-squared
#
# A survey was conducted to see if there is a relationship between gender and littering behavior.
#
# Question:
# "Is gender associated with littering behavior?"
#
# Each row represents one person.

# %%
url = "https://github.com/robitussin/CCDATSCL_EXERCISES/blob/f56f00991116fcb717a8827d324aa6f599dea366/litteringdata.csv?raw=true"

df_littering_data = pd.read_csv(url)
df_littering_data
# Out:
#     ID  Gender Litter
# 0    1    Male    Yes
# 1    2    Male    Yes
# 2    3    Male    Yes
# 3    4    Male    Yes
# 4    5    Male    Yes
# 5    6    Male    Yes
# 6    7    Male    Yes
# 7    8    Male    Yes
# 8    9    Male    Yes
# 9   10    Male    Yes
# 10  11    Male    Yes
# 11  12    Male    Yes
# 12  13    Male     No
# 13  14    Male     No
# 14  15    Male     No
# 15  16    Male     No
# 16  17    Male     No
# 17  18    Male     No
# 18  19    Male     No
# 19  20    Male     No
# 20  21  Female    Yes
# 21  22  Female    Yes
# 22  23  Female    Yes
# 23  24  Female    Yes
# 24  25  Female    Yes
# 25  26  Female    Yes
# 26  27  Female     No
# 27  28  Female     No
# 28  29  Female     No
# 29  30  Female     No
# 30  31  Female     No
# 31  32  Female     No
# 32  33  Female     No
# 33  34  Female     No
# 34  35  Female     No
# 35  36  Female     No
# 36  37  Female     No
# 37  38  Female     No
# 38  39  Female     No
# 39  40  Female     No

# %% [markdown]
# Count the number of observations in each category for Gender and Litter separately.

# %%
#put your answer here

print('Counts for Gender:')
print(df_littering_data['Gender'].value_counts())

print('\nCounts for Litter:')
print(df_littering_data['Litter'].value_counts())
# Out:
# Counts for Gender:
# Gender
# Male      20
# Female    20
# Name: count, dtype: int64
#
# Counts for Litter:
# Litter
# No     22
# Yes    18
# Name: count, dtype: int64

# %% [markdown]
# Using `pd.crosstab()`, create a contingency table showing counts of littering behavior for each gender.
# - Write down the row totals, column totals, and grand total from the table.

# %%
# put your answer here

contingency_table = pd.crosstab(df_littering_data['Gender'], df_littering_data['Litter'], margins=True)
contingency_table
# Out:
# Litter  No  Yes  All
# Gender
# Female  14    6   20
# Male     8   12   20
# All     22   18   40

# %% [markdown]
# State the null hypothesis (H₀) and alternative hypothesis (H₁) for this chi-squared test.

# %%
# put your answer here

print('Null Hypothesis: There is no relationship between gender and littering behavior.')
print('Alternative Hypothesis: There is a relationship between gender and littering behavior.')
# Out:
# Null Hypothesis: There is no relationship between gender and littering behavior.
# Alternative Hypothesis: There is a relationship between gender and littering behavior.

# %% [markdown]
# Use scipy.stats.chi2_contingency to calculate:
# - Chi-squared statistic
# - p-value
# - Degrees of freedom

# %% [markdown]
# Using a significance level of `α = 0.05`, determine whether to reject or fail to reject H₀.

# %%
# put your answer here

chi2, p, dof, expected = chi2_contingency(contingency_table)

print('Chi-squared statistic: ', chi2)
print('p-value: ', p)
print('Degrees of freedom: ', dof)
# Out:
# Chi-squared statistic:  3.6363636363636367
# p-value:  0.45744899514884474
# Degrees of freedom:  4

# %% [markdown]
# Interpret your results. Is there evidence that gender and littering behavior are associated?

# %%
# put your answer here

print('Question: Is gender associated with littering behavior?')

if p < 0.05:
    print('\nReject H0. There is a relationship between gender and littering behavior.')
else:
    print('\nFail to reject H0. There is no relationship between gender and littering behavior.')
# Out:
# Question: Is gender associated with littering behavior?
#
# Fail to reject H0. There is no relationship between gender and littering behavior.
